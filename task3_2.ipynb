# %%
from google.colab import files
dfile = files.upload()
# Out:
#      <input type="file" id="files-ae7ceb41-fd34-4b14-a550-99a72e202ea1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae7ceb41-fd34-4b14-a550-99a72e202ea1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BinanceSampleData.json to BinanceSampleData (1).json

# %%
print(dfile)
# Out:
# {'BinanceSampleData.json': b'[\r\n  {\r\n    "e": "aggTrade",\r\n    "E": 1624711283248,\r\n    "a": 647022008,\r\n    "s": "BTCUSDT",\r\n    "p": "31814.09",\r\n    "q": "0.356",\r\n    "f": 1093763683,\r\n    "l": 1093763684,\r\n    "T": 1624711283094,\r\n    "m": false\r\n  },\r\n  {\r\n    "e": "aggTrade",\r\n    "E": 1624711283269,\r\n    "a": 647022009,\r\n    "s": "BTCUSDT",\r\n    "p": "31814.08",\r\n    "q": "0.018",\r\n    "f": 1093763685,\r\n    "l": 1093763685,\r\n    "T": 1624711283263,\r\n    "m": true\r\n  },\r\n  {\r\n    "e": "aggTrade",\r\n    "E": 1624711283323,\r\n    "a": 647022010,\r\n    "s": "BTCUSDT",\r\n    "p": "31814.09",\r\n    "q": "0.006",\r\n    "f": 1093763686,\r\n    "l": 1093763686,\r\n    "T": 1624711283264,\r\n    "m": false\r\n  },\r\n  {\r\n    "e": "aggTrade",\r\n    "E": 1624711283325,\r\n    "a": 647022011,\r\n    "s": "BTCUSDT",\r\n    "p": "31814.08",\r\n    "q": "0.015",\r\n    "f": 1093763687,\r\n    "l": 1093763688,\r\n    "T": 162471128
# ...

# %%
for key in upload.keys():
  print(key)
# Out:
# BinanceSampleData.json

# %%
for key in dfile.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=key, length=len(dfile[key])))
# Out:
# User uploaded file "BinanceSampleData.json" with length 259973 bytes
